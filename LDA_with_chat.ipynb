# %%
import matplotlib.pyplot as plt

plt.hist(X_lda[y==0], bins=30, alpha=0.7, color='red', label='No')
plt.hist(X_lda[y==1], bins=30, alpha=0.7, color='blue', label='Yes')
plt.title("LDA Projection Histogram")
plt.xlabel("LD1 values")
plt.ylabel("Count")
plt.legend()
plt.show()
